# %% [markdown]
# ![2019-01-26%2021_47_17-Igor%20Pro%208.00%2064-bit%20-%20%5BLayout0_Graph0,Graph2,text0%5D.png](attachment:2019-01-26%2021_47_17-Igor%20Pro%208.00%2064-bit%20-%20%5BLayout0_Graph0,Graph2,text0%5D.png)

# %% [markdown]
# A code:
#
# $-a_{Theta} = 0.475$
#
# $-\lambda = 17.84437703$
#
# R code:
#
# $-a = 107.041969$

# %% [markdown]
# ![contrast14.png](attachment:contrast14.png)

# %% [markdown]
# A code:
#
# $-a_{Theta} = 0.35$
#
# $-\lambda = 14.2286956$
#
# R code:
#
# $-a = 66.1519438$

# %% [markdown]
# ![contrast9.png](attachment:contrast9.png)

# %% [markdown]
# A code:
#
# $-a_{Theta} = 0.225$
#
# $-\lambda = 10.6922457$
#
# R code:
#
# $-a = 34.3485907$
